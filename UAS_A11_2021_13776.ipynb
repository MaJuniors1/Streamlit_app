# %% [markdown]
# Nama : Farrel Riyan Wibowo
#
# Nim : A11.2021.13776
#
# Kelas : DS-03
#
# Link YT : https://youtu.be/VnIm1H1UEDM?si=2A3GbELVxhNCLBV0
#
# LInk GitHub : https://github.com/MaJuniors1/Streamlit_app/tree/main

# %% [markdown]
# #Pengumpulan Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

water_data = pd.read_csv('/content/drive/MyDrive/Dataset/water_potability.csv')
water_data.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
water_data.tail()
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 3271    526.424171       13.894419        66.687695   4.435821           1
# 3272    392.449580       19.903225              NaN   2.798243           1
# 3273    432.044783       11.039070        69.845400   3.298875           1
# 3274    402.883113       11.168946        77.488213   4.708658           1
# 3275    327.459760       16.140368        78.698446   2.309149           1

# %% [markdown]
# #Menelaah Data

# %%
water_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
water_data.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# ...

# %%
water_data.nunique()
# Out:
# ph                 2785
# Hardness           3276
# Solids             3276
# Chloramines        3276
# Sulfate            2495
# Conductivity       3276
# Organic_carbon     3276
# Trihalomethanes    3114
# Turbidity          3276
# Potability            2
# dtype: int64

# %% [markdown]
# #Validasi dan Visualisasi Data

# %%
#Memeriksa apakah ada missing value
print("Jumlah Nilai Hilang per Kolom:")
print(water_data.isnull().sum())
# Out:
# Jumlah Nilai Hilang per Kolom:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
# Imputasi nilai hilang dengan mean
water_data.fillna(water_data.mean(), inplace=True)

# %%
# Memeriksa apakah ada missing value
print("Jumlah Nilai Hilang Sesudah Imputasi Menggunakan Mean :")
print(water_data.isnull().sum())
# Out:
# Jumlah Nilai Hilang Sesudah Imputasi Menggunakan Mean :
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
# Visualisasi Outlier dengan Box Plot
plt.figure(figsize=(15, 10))
for i, column in enumerate(water_data.columns[:-1]):  # Kolom terakhir adalah 'Potability'
    plt.subplot(3, 3, i + 1)
    sns.boxplot(y=water_data[column])
    plt.title(f"Box Plot: {column}")
plt.tight_layout()
plt.show()

# %%
# Visualisasi Distribusi Data Sebelum Resampling
plt.figure(figsize=(15, 10))
for i, column in enumerate(water_data.columns[:-1]):
    plt.subplot(3, 3, i + 1)
    sns.histplot(water_data[column], kde=True, bins=30)
    plt.title(f"Distribusi: {column}")
plt.tight_layout()
plt.show()

# %%
# Oversampling kelas minoritas (opsional, jika diperlukan)
from imblearn.over_sampling import RandomOverSampler

# Visualisasi Distribusi Data Setelah Resampling
ros = RandomOverSampler(random_state=42)
X_resampled, y_resampled = ros.fit_resample(water_data.drop('Potability', axis=1), water_data['Potability'])
data_resampled = pd.concat([pd.DataFrame(X_resampled, columns=water_data.columns[:-1]), pd.Series(y_resampled, name='Potability')], axis=1)

plt.figure(figsize=(15, 10))
for i, column in enumerate(data_resampled.columns[:-1]):
    plt.subplot(3, 3, i + 1)
    sns.histplot(data_resampled[column], kde=True, bins=30)
    plt.title(f"Distribusi (Resampled): {column}")
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(

# %%
#Mengidentifikasi jenis kolom (variabel) dalam sebuah dataframe berdasarkan tipe data dan karakteristiknya

def grab_col_names(dataframe, cat_th = 10, car_th = 20): #  memisahkan kolom dalam dataset berdasarkan tipe dan karakteristiknya.

    cat_cols = [col for col in dataframe.columns if str(dataframe[col].dtypes) in ["category", "object", "bool"]] # kolom kategorikal (tipe "category", "object", "bool", atau numerik dengan unique values < cat_th).
    num_but_cat = [col for col in dataframe.columns if str(dataframe[col].dtypes) in ["int64", "float64"] and dataframe[col].nunique() < cat_th] # kolom numerik yang bertindak seperti kategorikal (berdasarkan jumlah unique values).
    cat_but_car = [col for col in dataframe.columns if str(dataframe[col].dtypes) in ["category", "object"] and dataframe[col].nunique() > car_th] # kolom kategorikal dengan unique values > car_th (high cardinality).

    cat_cols = cat_cols + num_but_cat
    cat_cols = [col for col in cat_cols if col not in cat_but_car]

    # kolom numerik murni (int64, float64) yang bukan kategorikal.
    num_cols = [col for col in dataframe.columns if str(dataframe[col].dtypes) in ["int64", "float64"]]
    num_cols = [col for col in num_cols if col not in cat_cols]

    print(f"Jumlah observasi: {dataframe.shape[0]}")
    print(f"Jumlah variabel: {dataframe.shape[1]}")
    print(f"Kolom kategorikal: {len(cat_cols)}")
    print(f"Kolom Numerik: {len(num_cols)}")
    print(f"Kategori tapi kardinal: {len(cat_but_car)}")
    print(f"Numerik tapi kategorikal: {len(num_but_cat)}")

    # mengembalikan daftar kolom yang dikelompokkan berdasarkan tipe (cat_cols, num_cols, cat_but_car).
    return cat_cols, num_cols, cat_but_car

# %%
# Memanggil fungsi grab_col_names yang telah didefinisikan untuk memisahkan kolom-kolom dalam dataframe menjadi tiga kategori berdasarkan tipe data dan karakteristik distribusinya
cat_cols, num_cols, cat_but_car = grab_col_names(water_data)
# Out:
# Jumlah observasi: 3276
# Jumlah variabel: 10
# Kolom kategorikal: 1
# Kolom Numerik: 9
# Kategori tapi kardinal: 0
# Numerik tapi kategorikal: 1

# %% [markdown]
# # Menentukan Object Data

# %%
# Fitur yang digunakan
water_data.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
water_data.tail()
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 3271    526.424171       13.894419        66.687695   4.435821           1
# 3272    392.449580       19.903225              NaN   2.798243           1
# 3273    432.044783       11.039070        69.845400   3.298875           1
# 3274    402.883113       11.168946        77.488213   4.708658           1
# 3275    327.459760       16.140368        78.698446   2.309149           1

# %%
water_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %% [markdown]
# # Membersihkan Data

# %%
#Memeriksa apakah ada missing value
print("Jumlah Nilai Hilang per Kolom:")
print(water_data.isnull().sum())
# Out:
# Jumlah Nilai Hilang per Kolom:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
# Imputasi nilai hilang dengan mean
water_data.fillna(water_data.mean(), inplace=True)

# %%
# Memeriksa apakah ada missing value
print("Jumlah Nilai Hilang Sesudah Imputasi Menggunakan Mean :")
print(water_data.isnull().sum())
# Out:
# Jumlah Nilai Hilang Sesudah Imputasi Menggunakan Mean :
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
# Korelasi Heatmap
plt.figure(figsize=(10, 8))
corr = water_data.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Korelasi Heatmap")
plt.show()

# %%
# Distribusi Histogram Plot
fig, axes = plt.subplots(3, 3, figsize=(15, 10))  # Inisialisasi axes menggunakan plt.subplots()
# fig, axes = plt.subplots(3, 3, figsize=(15, 10))  # Tambahkan baris ini

for i, column in enumerate(water_data.columns[:-1]):  # Kolom terakhir adalah 'Potability'
    # plt.subplot(3, 3, i + 1)  # Hapus baris ini
    sns.histplot(water_data[column], kde=True, bins=30, ax=axes[i // 3, i % 3])  # Gunakan ax=axes[i // 3, i % 3] untuk menentukan subplot
    axes[i // 3, i % 3].set_ylabel('Frequency')  # Ubah axes[i] menjadi axes[i // 3, i % 3]
    axes[i // 3, i % 3].set_title(f"Distribution of {column}")  # Ubah axes[i] menjadi axes[i // 3, i % 3]
plt.tight_layout()
plt.show()

# %% [markdown]
# # Konstruksi Data

# %%
water_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               3276 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          3276 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3276 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
water_data.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0  7.080795  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246  333.775777    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884  333.775777    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
data_clean = water_data.drop_duplicates() # Menghapus baris duplikat dari data
print("Seluruh Baris Duplicates")
data_clean[data_clean.duplicated(keep=False)] # Menampilkan baris dup
# Out:
# Seluruh Baris Duplicates
# Empty DataFrame
# Columns: [ph, Hardness, Solids, Chloramines, Sulfate, Conductivity, Organic_carbon, Trihalomethanes, Turbidity, Potability]
# Index: []

# %%
# Memberikan informasi detail tentang struktur dataframe
data_clean.info() # data_clean sebagai dataset yang telah bersih
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               3276 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          3276 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3276 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
data_clean.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0  7.080795  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246  333.775777    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884  333.775777    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %% [markdown]
# # Pemodelan

# %%
# Memisahkan fitur (X) dan target (y) dalam dataset
X = data_clean.drop("Potability", axis = 1)
y = data_clean["Potability"]

# %%
# Membuat visualisasi berupa diagram batang (bar plot) yang menunjukkan jumlah individu yang termasuk dalam masing-masing kategori pada kolom Potability
data_clean['Potability'].value_counts().plot(kind='bar',figsize=(10,6),color=['green','blue'])
plt.title("Count of the Potability person")
plt.xticks(rotation=0);

# %%
# Library untuk membantu oversampling dengan teknik SMOTE
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(random_state=42) # Inisialisasi SMOTE
X_smote_resampled, y_smote_resampled = smote.fit_resample(X, y) # Mengaplikasikan oversampling pada dataset
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_tags.py:354: FutureWarning: The SMOTE or classes from which it inherits use `_get_tags` and `_more_tags`. Please define the `__sklearn_tags__` method, or inherit from `sklearn.base.BaseEstimator` and/or other appropriate mixins such as `sklearn.base.TransformerMixin`, `sklearn.base.ClassifierMixin`, `sklearn.base.RegressorMixin`, and `sklearn.base.OutlierMixin`. From scikit-learn 1.7, not defining `__sklearn_tags__` will raise an error.
#   warnings.warn(

# %%
plt.figure(figsize=(12, 4)) # Membuat sebuah figure (gambar) baru dengan ukuran 12x4 inci

new_df1 = pd.DataFrame(data=y) # Membuat DataFrame baru, new_df1

plt.subplot(1, 2, 1)
new_df1.value_counts().plot(kind='bar',figsize=(10,6),color=['green','blue'])
plt.title("Potability before over sampling with SMOTE ")
plt.xticks(rotation=0);


plt.subplot(1, 2, 2) # Membuat subplot pertama dengan layout 1 baris dan 2 kolom
new_df2 = pd.DataFrame(data=y_smote_resampled)


new_df2.value_counts().plot(kind='bar',figsize=(10,6),color=['green','blue']) # Menghitung frekuensi masing-masing kategori (0 dan 1), membuat diagram batang (bar plot) berdasarkan frekuensi kategori
plt.title("Potability after over sampling with SMOTE") # Memberikan judul pada subplot pertama
plt.xticks(rotation=0); # Menetapkan label sumbu-x (kategori 0 dan 1) untuk tetap dalam posisi horizontal

plt.tight_layout() # Mengatur layout agar subplot tidak saling tumpang tindih
plt.show() # Menampilkan kedua plot dalam satu figure

# %%
from sklearn.model_selection import train_test_split # Library untuk membantu memisahkan data menjadi dataset latih dan dataset validasi
X_train, X_test, y_train, y_test = train_test_split(X_smote_resampled, y_smote_resampled, test_size=0.2, random_state=42,stratify=y_smote_resampled) # 80% data latih, 20% data test

# %%
from sklearn.naive_bayes import GaussianNB # Mengimplementasikan algoritma Naive Bayes
from sklearn.ensemble import RandomForestClassifier # Mengimplementasikan algoritma Random Forest
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.neighbors import KNeighborsClassifier # Mengimplementasikan K-Nearest Neighbors (KNN)

# %%
# Inisialisasi
nb = GaussianNB()
rf = RandomForestClassifier(random_state=42)
knn = KNeighborsClassifier()
models = {
"Naive Bayes": nb,
"Random Forest": rf,
"K-Nearest Neighbors": knn,
}

# %%
nb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
nb_y_pred = nb.predict(X_test)
accuracy_nb = round(accuracy_score(y_test, nb_y_pred), 3)

cm_nb = confusion_matrix(y_test, nb_y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm_nb, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix - Naive Bayes')
plt.xlabel('Prediksi')
plt.ylabel('Aktual')
plt.show()

print(classification_report(y_test, nb_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.64      0.60       400
#            1       0.59      0.52      0.55       400
#
#     accuracy                           0.58       800
#    macro avg       0.58      0.58      0.58       800
# weighted avg       0.58      0.58      0.58       800

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
rf_y_pred = rf.predict(X_test)
accuracy_rf = round(accuracy_score(y_test, rf_y_pred), 3)

cm_rf = confusion_matrix(y_test, rf_y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Greens')
plt.title('Confusion Matrix - Random Forest')
plt.xlabel('Prediksi')
plt.ylabel('Aktual')
plt.show()
print(classification_report(y_test, rf_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.73      0.71       400
#            1       0.72      0.67      0.69       400
#
#     accuracy                           0.70       800
#    macro avg       0.70      0.70      0.70       800
# weighted avg       0.70      0.70      0.70       800

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
knn_y_pred = knn.predict(X_test)
accuracy_knn = round(accuracy_score(y_test, knn_y_pred), 3)

cm_knn = confusion_matrix(y_test, knn_y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm_knn, annot=True, fmt='d', cmap='Greys')
plt.title('Confusion Matrix - K-Nearest Neighbors')
plt.xlabel('Prediksi')
plt.ylabel('Aktual')
plt.show()
print(classification_report(y_test, knn_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.57      0.59       400
#            1       0.59      0.62      0.61       400
#
#     accuracy                           0.60       800
#    macro avg       0.60      0.60      0.60       800
# weighted avg       0.60      0.60      0.60       800

# %%
# Membuat dataframe menggunakan library pandas
models = pd.DataFrame({
    'Model': ['GaussianNB', 'Random FOrest Classifier', 'KNN'],
    'Accuracy': [accuracy_nb, accuracy_rf, accuracy_knn]
})
# Mengurutkan kolom 'Score' dari nilai tertinggi ke nilai terendah
models.sort_values(by = 'Accuracy', ascending = False)
# Out:
#                       Model  Accuracy
# 1  Random FOrest Classifier     0.701
# 2                       KNN     0.598
# 0                GaussianNB     0.578

# %%
# Membuat Bar Plot
plt.figure(figsize=(8, 5))
bars = plt.bar(models['Model'], models['Accuracy'], color=sns.palettes.mpl_palette('Dark2'))

# Menambahkan Label dan Judul
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.title('Model Accuracy Comparison')
plt.ylim(0, 1)  # Karena nilai accuracy biasanya antara 0 dan 1
plt.xticks(rotation=45)

# Menambahkan anotasi nilai accuracy di atas setiap bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + .005, round(yval,3), ha='center', va='bottom')

plt.show()

# %% [markdown]
# # Evaluasi

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
# Inisialisasi model Logistic Regression dengan regularisasi L1
selector = SelectFromModel (estimator=LogisticRegression (penalty='l1', solver='liblinear', C=1), max_features=5)
# Melakukan fit pada data training
selector.fit(X_train, y_train)
# Mendapatkan fitur-fitur yang terpilih
selected_features = X_train.columns[selector.get_support()]
# Mencetak fitur-fitur yang terpilih
print("Fitur yang terpilih:", selected_features)
# Membuat dataset baru dengan fitur-fitur yang terpilih
X_train_selected = selector.transform(X_train)
X_test_selected = selector.transform(X_test)
# Out:
# Fitur yang terpilih: Index(['ph', 'Chloramines', 'Organic_carbon', 'Trihalomethanes', 'Turbidity'], dtype='object')

# %%
from sklearn.model_selection import RandomizedSearchCV # Import the necessary class
nb = GaussianNB()
param_grid = {
    'var_smoothing': np.logspace(0,-9, num=100)
}
nb_search = RandomizedSearchCV(
    nb,
    param_distributions=param_grid,
    n_iter=10, # Jumlah iterasi pencarian
    cv=5, # Jumlah fold untuk cross-validation
    verbose=2, # Menampilkan detail proses pencarian
    random_state=42, # Untuk reproduksibilitas
    n_jobs=-1 # Gunakan semua core prosesor
)
nb_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# RandomizedSearchCV(cv=5, estimator=GaussianNB(), n_jobs=-1,
#                    param_distributions={'var_smoothing': array([1.00000000e+00, 8.11130831e-01, 6.57933225e-01, 5.33669923e-01,
#        4.32876128e-01, 3.51119173e-01, 2.84803587e-01, 2.31012970e-01,
#        1.87381742e-01, 1.51991108e-01, 1.23284674e-01, 1.00000000e-01,
#        8.11130831e-02, 6.57933225e-02, 5.33669923e-02, 4.32876128e-02,
#        3.5111917...
#        1.23284674e-07, 1.00000000e-07, 8.11130831e-08, 6.57933225e-08,
#        5.33669923e-08, 4.32876128e-08, 3.51119173e-08, 2.84803587e-08,
#        2.31012970e-08, 1.87381742e-08, 1.51991108e-08, 1.23284674e-08,
#        1.00000000e-08, 8.11130831e-09, 6.57933225e-09, 5.33669923e-09,
#        4.32876128e-09, 3.51119173e-09, 2.84803587e-09, 2.31012970e-09,
#        1.87381742e-09, 1.51991108e-09, 1.23284674e-09, 1.00000000e-09])},
#                    random_state=42, verbose=2)

# %%
# Dapatkan parameter terbaik
print(f"Best Parameters: {nb_search.best_params_}")
print(f"Best Cross-Validation Score: {nb_search.best_score_}")

# Evaluasi model pada data test
best_nb = nb_search.best_estimator_
y_pred = best_nb.predict(X_test)

# Tampilkan hasil evaluasi
accuracy_nb_after = accuracy_score(y_test, y_pred) # Assign the accuracy score to the variable 'accuracy'
print(f"Tes Accuracy: {accuracy}")
print(f"Confusion Matrix: \n{confusion_matrix(y_test, y_pred)}")
print(f"Classification Report: \n{classification_report(y_test, y_pred)}")

model_comparison = pd.DataFrame({
    'Model': ['GaussianNB (Sebelum)', 'GaussianNB (Setelah)'],
    'Accuracy': [accuracy_nb, accuracy] # accuracy_nb adalah akurasi model sebelum dioptimalkan
})
print(model_comparison)
# Out:
# Best Parameters: {'var_smoothing': 2.848035868435799e-08}
# Best Cross-Validation Score: 0.540359937402191
# Tes Accuracy: 0.56875
# Confusion Matrix:
# [[268 132]
#  [213 187]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.56      0.67      0.61       400
#            1       0.59      0.47      0.52       400
#
#     accuracy                           0.57       800
#    macro avg       0.57      0.57      0.56       800
# weighted avg       0.57      0.57      0.56       800
#
#                   Model  Accuracy
# 0  GaussianNB (Sebelum)   0.57800
# 1  GaussianNB (Setelah)   0.56875

# %%
param_grid = {
    "n_estimators": [50, 100], #jumlah pohon keputusan (semakin banyak semakin akurat tapi komputasi semakin lama)
    "max_depth": [ 10, 15], # kedalaman maksimum
    "min_samples_leaf": [1, 2], # jumlah minimum sample
    "min_samples_split": [2, 5], # menentukan sample minimum untuk membagi node
    "max_features": ["sqrt", "log2"], # jumlah fitur yang digunakan dalam setiap pohon untuk mencari split terbaik.
}
rf = RandomForestClassifier(random_state=42)
rf_search = RandomizedSearchCV(rf, param_grid, n_iter=3, cv=5, n_jobs=-1)
rf_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#                    n_iter=3, n_jobs=-1,
#                    param_distributions={'max_depth': [10, 15],
#                                         'max_features': ['sqrt', 'log2'],
#                                         'min_samples_leaf': [1, 2],
#                                         'min_samples_split': [2, 5],
#                                         'n_estimators': [50, 100]})

# %%
# Dapatkan parameter terbaik
print(f"Best Parameters: {rf_search.best_params_}")
print(f"Best Cross-Validation Score: {rf_search.best_score_}")

# Evaluasi model pada data test
best_rf = rf_search.best_estimator_
y_pred = best_rf.predict(X_test)

# Tampilkan hasil evaluasi
print(f"Tes Accuracy: {accuracy_score (y_test, y_pred)}")
print(f"Confusion Matrix: \n{confusion_matrix(y_test, y_pred)}")
print(f"Classification Report: \n{classification_report(y_test, y_pred)}")

model_comparison = pd.DataFrame({
    'Model': ['Random Forest (Sebelum)', 'Random Forest (Setelah)'],
    'Accuracy': [accuracy_rf, accuracy] # accuracy_rf adalah akurasi model sebelum dioptimalkan
})
print(model_comparison)
# Out:
# Best Parameters: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 15}
# Best Cross-Validation Score: 0.6695901799687011
# Tes Accuracy: 0.70875
# Confusion Matrix:
# [[286 114]
#  [119 281]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.71      0.71       400
#            1       0.71      0.70      0.71       400
#
#     accuracy                           0.71       800
#    macro avg       0.71      0.71      0.71       800
# weighted avg       0.71      0.71      0.71       800
#
#                      Model  Accuracy
# 0  Random Forest (Sebelum)   0.70100
# 1  Random Forest (Setelah)   0.56875

# %%
# Define the parameter grid for KNN
param_grid = {
    'n_neighbors': [3, 5, 7, 9, 11], # Number of neighbors to consider
    'weights': ['uniform', 'distance'], # Weight function used in prediction
    'metric': ['euclidean', 'manhattan', 'minkowski'], # Distance metric
    'p': [1, 2] # Power parameter for the Minkowski metric
}

# Initialize RandomizedSearchCV
knn = KNeighborsClassifier()
random_search = RandomizedSearchCV(estimator=knn, param_distributions=param_grid, n_iter=50, cv=5, verbose=2, n_jobs=-1, random_state=42, scoring='accuracy')

# Train the model with RandomizedSearchCV
random_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# RandomizedSearchCV(cv=5, estimator=KNeighborsClassifier(), n_iter=50, n_jobs=-1,
#                    param_distributions={'metric': ['euclidean', 'manhattan',
#                                                    'minkowski'],
#                                         'n_neighbors': [3, 5, 7, 9, 11],
#                                         'p': [1, 2],
#                                         'weights': ['uniform', 'distance']},
#                    random_state=42, scoring='accuracy', verbose=2)

# %%
# Display best parameters and score
print(f"Best Parameters: {random_search.best_params_}")
print(f"Best Cross-Validation Score: {random_search.best_score_}")

# Evaluate on test set
best_knn = random_search.best_estimator_
y_pred = best_knn.predict(X_test)

print(f"Test Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"Confusion Matrix:\n{confusion_matrix(y_test, y_pred)}")
print(f"Classification Report:\n{classification_report(y_test, y_pred)}")

# Comparison with previous model (if applicable)
accuracy_random_search = accuracy_score(y_test, y_pred)

# Example: assuming accuracy_knn_before is the accuracy of a previous KNN model
accuracy_knn_before = 0.75  # Placeholder value

model_comparison = pd.DataFrame({
    'Model': ['KNN (Sebelum)', 'KNN (Setelah)'],
    'Accuracy': [accuracy_knn_before, accuracy_random_search]
})

print("\nPerbandingan Akurasi Model:")
print(model_comparison)
# Out:
# Best Parameters: {'weights': 'distance', 'p': 2, 'n_neighbors': 3, 'metric': 'euclidean'}
# Best Cross-Validation Score: 0.631101330203443
# Test Accuracy: 0.6275
# Confusion Matrix:
# [[222 178]
#  [120 280]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.65      0.56      0.60       400
#            1       0.61      0.70      0.65       400
#
#     accuracy                           0.63       800
#    macro avg       0.63      0.63      0.63       800
# weighted avg       0.63      0.63      0.63       800
#
#
# Perbandingan Akurasi Model:
#            Model  Accuracy
# 0  KNN (Sebelum)    0.7500
# 1  KNN (Setelah)    0.6275

# %%
import matplotlib.pyplot as plt

# Assuming you have calculated accuracies and stored them in these variables
accuracy_model_nb = accuracy_nb  # Assuming accuracy_nb from previous cells
accuracy_model_knn = accuracy_knn  # Assuming accuracy_knn from previous cells
accuracy_model_rfc = accuracy_rf  # Assuming accuracy_rf from previous cells
accuracy_nbcustom = accuracy # Assuming accuracy from Naive Bayes optimization cell
accuracy_knncustom = accuracy_random_search # Assuming accuracy_random_search from KNN optimization cell
accuracy_rfcustom = accuracy_score(y_test, y_pred)  # Assuming y_pred from Random Forest optimization cell


models = ['Naive Bayes', 'KNN', 'Random Forest']
initial_accuracies = [accuracy_model_nb*100, accuracy_model_knn*100, accuracy_model_rfc*100]
tuned_accuracies = [accuracy_nbcustom*100, accuracy_knncustom*100, accuracy_rfcustom*100]

x = range(len(models))
width = 0.35
fig, ax = plt.subplots(figsize=(10, 6))
rects1 = ax.bar(x, initial_accuracies, width, label='Sebelum Evaluasi')
rects2 = ax.bar([i + width for i in x], tuned_accuracies, width, label='Setelah Evaluasi')
ax.set_ylabel('Akurasi (%)')
ax.set_title('Perbandingan Akurasi Model')
ax.set_xticks([i + width / 2 for i in x])
ax.set_xticklabels(models)
ax.legend()

# Menambahkan label nilai di atas setiap bar
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.2f}%',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)
fig.tight_layout()
plt.show()

# %% [markdown]
# # Deployment

# %% [markdown]
# Link Deploy : https://waterrwantaso.streamlit.app/

# %% [markdown]
# # Kesimpulan

# %% [markdown]
# *   Tingkat Akurasi Tiap Algoritma
#
#
# 1.   Naive Bayes sebelum proses 57.80% , sesudah evaluasi 56.88%
# 2.   KNN sebelum proses 59.80% , sesudah evaluasi 62.75%
# 3.   Random Forest sebelum proses 70.10% , sesudah evaluasi 56.88%
#
#
# *   Setiap algoritma memiliki keunggulan dan keterbatasannya. Naive Bayes unggul dalam kecepatan dan efisiensi, tetapi kurang mampu menangani data yang kompleks atau memiliki fitur saling bergantung. KNN relatif sederhana dan efektif pada dataset kecil tetapi memerlukan optimasi untuk parameter K serta memiliki performa yang cenderung menurun pada dataset besar. Random Forest, meskipun mampu menghasilkan akurasi awal tinggi dengan menangkap pola kompleks, menunjukkan potensi overfitting dalam kasus ini.
#
#
# *   Berdasarkan analisis ini, algoritma KNN direkomendasikan sebagai pilihan paling efektif untuk kasus ini karena peningkatan akurasi setelah evaluasi menunjukkan stabilitas dan kemampuan beradaptasi yang baik terhadap data. Optimasi lebih lanjut pada parameter K dapat membuat algoritma ini semakin optimal untuk digunakan.
